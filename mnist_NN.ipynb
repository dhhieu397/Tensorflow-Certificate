# %% [markdown]
# <a href="https://colab.research.google.com/github/dhhieu397/Tensorflow-Certificate/blob/master/mnist_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
# Load data
#mnist = tf.keras.datasets.mnist
(trainX, trainY), (testX, testY) = mnist.load_data()

# %%
# Chuẩn hoá dữ liệu
trainX = trainX/255.0
testY = testY/255.0

# %%
#Hiển thị 1 ảnh
import matplotlib.pyplot as plt
plt.imshow(trainX[0])

# %%
trainX.shape
# Out:
# (60000, 28, 28)

# %%
testX.shape
# Out:
# (10000, 28, 28)

# %%
# Xây dựng cấu trúc mạng
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

# %%
model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# ...
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile thuật toán
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

# %%
# Training
model.fit(trainX, trainY, verbose=1, epochs=500, validation_data=(testX, testY))
# Out:
# Epoch 1/500
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2040 - acc: 0.9392 - val_loss: 2987.7610 - val_acc: 0.0940
# Epoch 2/500
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0837 - acc: 0.9737 - val_loss: 3650.3081 - val_acc: 0.0965
# Epoch 3/500
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0576 - acc: 0.9818 - val_loss: 3817.7769 - val_acc: 0.0969
# Epoch 4/500
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0431 - acc: 0.9861 - val_loss: 4258.6689 - val_acc: 0.0972
# Epoch 5/500
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0335 - acc: 0.9893 - val_loss: 5090.3789 - val_acc: 0.0972
# Epoch 6/500
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0296 - acc: 0.9909 - val_loss: 4978.7700 - val_acc: 0.0969
# Epoch 7/500
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0249 - acc: 0.9917 - val_loss: 5974.3223 - val_acc: 0.0967
# ...
